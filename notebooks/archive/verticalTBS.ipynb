# %%
# !pip install git+https://github.com/ourownstory/neural_prophet.git --upgrade
# Out:
# Collecting git+https://github.com/ourownstory/neural_prophet.git
#   Cloning https://github.com/ourownstory/neural_prophet.git to /private/var/folders/t6/zc4n8b2j6rdcj9p7xb7gxm0h0000gn/T/pip-req-build-dp9oh2q1
#   Running command git clone --filter=blob:none --quiet https://github.com/ourownstory/neural_prophet.git /private/var/folders/t6/zc4n8b2j6rdcj9p7xb7gxm0h0000gn/T/pip-req-build-dp9oh2q1
#   Resolved https://github.com/ourownstory/neural_prophet.git to commit de24e5d041f4a9d5b2b262d7e530b8243d9a8b1f
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting holidays>=0.11.3.1
#   Using cached holidays-0.14.2-py3-none-any.whl (179 kB)
# Collecting ipywidgets>=7.5.1
#   Downloading ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 2.1 MB/s eta 0:00:00m eta 0:00:01
# Collecting matplotlib>=2.0.0
#   Downloading matplotlib-3.5.3-cp38-cp38-macosx_10_9_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 15.3 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting torch>=1.8.0
#   Downloading torch-1.12.1-cp38-none-macosx_10_9_x86_64.whl (137.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 MB 14.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting convertdate>=2.1.2
#   Using cached convertdate-2.4.0-py3-none-any.whl (47 kB)
# Collecting torch-lr-finder>=0.2.1
#   Using cached torch_lr_finder-0.2.1-py3-none-any.whl (11 kB)
# Collecting LunarCalendar>=0.0.9
#   Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting pandas>=1.0.4
#   Downloading pandas-1.4.3-cp38-cp38-macosx_10_9_x86_64.whl (11.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 35.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from neuralprophet==0.3.3) (2.8.2)
# Collecting plotly>=4.14.3
#   Downloading plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 19.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting kaleido>=0.2.1
#   Using cached kaleido-0.2.1-py2.py3-none-macosx_10_11_x86_64.whl (85.2 MB)
# Collecting numpy>=1.15.4
#   Downloading numpy-1.23.1-cp38-cp38-macosx_10_9_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 33.0 MB/s eta 0:00:00m eta 0:00:010:0101
# Collecting tqdm>=4.50.2
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Collecting pymeeus<=1,>=0.3.13
#   Using cached PyMeeus-0.5.11-py3-none-any.whl
# Collecting korean-lunar-calendar
#   Using cached korean_lunar_calendar-0.2.1-py3-none-any.whl (8.0 kB)
# Collecting hijri-converter
#   Using cached hijri_converter-2.2.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: ipython>=4.0.0 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipywidgets>=7.5.1->neuralprophet==0.3.3) (8.4.0)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.1 MB/s eta 0:00:00m eta 0:00:01
# Collecting ipython-genutils~=0.2.0
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipywidgets>=7.5.1->neuralprophet==0.3.3) (5.3.0)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 7.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipywidgets>=7.5.1->neuralprophet==0.3.3) (6.15.1)
# Collecting ephem>=3.7.5.3
#   Using cached ephem-4.1.3-cp38-cp38-macosx_10_9_x86_64.whl (1.4 MB)
# Collecting pytz
#   Downloading pytz-2022.2-py2.py3-none-any.whl (504 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 504.7/504.7 kB 10.7 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from matplotlib>=2.0.0->neuralprophet==0.3.3) (3.0.9)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp38-cp38-macosx_10_10_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.5 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp38-cp38-macosx_10_9_x86_64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 1.9 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 kB 13.8 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from matplotlib>=2.0.0->neuralprophet==0.3.3) (21.3)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from python-dateutil>=2.8.0->neuralprophet==0.3.3) (1.16.0)
# Collecting typing-extensions
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: nest-asyncio in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (1.5.5)
# Requirement already satisfied: appnope in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (1.5.1)
# Requirement already satisfied: psutil in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (5.9.1)
# Requirement already satisfied: pyzmq>=17 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (19.0.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (7.0.6)
# Requirement already satisfied: tornado>=6.1 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (61.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (4.8.0)
# Requirement already satisfied: stack-data in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.3.0)
# Requirement already satisfied: backcall in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (2.12.0)
# Requirement already satisfied: decorator in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (3.0.30)
# Collecting notebook>=4.4.1
#   Downloading notebook-6.4.12-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 28.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (4.11.1)
# Requirement already satisfied: entrypoints in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.4)
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 3.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting terminado>=0.8.3
#   Downloading terminado-0.15.0-py3-none-any.whl (16 kB)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting nbconvert>=5
#   Downloading nbconvert-6.5.3-py3-none-any.whl (563 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.8/563.8 kB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nbformat
#   Downloading nbformat-5.4.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 2.1 MB/s eta 0:00:00
# Collecting prometheus-client
#   Downloading prometheus_client-0.14.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 1.7 MB/s eta 0:00:00
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.2.5)
# Requirement already satisfied: executing in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.9.1)
# Requirement already satisfied: asttokens in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/devinhopkins/opt/anaconda3/envs/np/lib/python3.8/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet==0.3.3) (0.2.2)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.6.6-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 2.2 MB/s eta 0:00:00
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 3.7 MB/s eta 0:00:00
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting bleach
#   Downloading bleach-5.0.1-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 5.3 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp38-cp38-macosx_10_9_x86_64.whl (13 kB)
# Collecting mistune<2,>=0.8.1
#   Using cached mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting tinycss2
#   Downloading tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Collecting lxml
#   Downloading lxml-4.9.1-cp38-cp38-macosx_10_15_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 27.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.1-py3-none-any.whl (22 kB)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.9.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.4 MB/s eta 0:00:00
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 1.6 MB/s eta 0:00:00
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp38-cp38-macosx_10_9_universal2.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 2.7 MB/s eta 0:00:00
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.8 MB/s eta 0:00:00
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Collecting cffi>=1.0.1
#   Downloading cffi-1.15.1-cp38-cp38-macosx_10_9_x86_64.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 5.5 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 3.6 MB/s eta 0:00:00
# Collecting zipp>=3.1.0
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Building wheels for collected packages: neuralprophet
#   Building wheel for neuralprophet (pyproject.toml) ... done
#   Created wheel for neuralprophet: filename=neuralprophet-0.3.3-py3-none-any.whl size=97750 sha256=3e5d1b688b0a69a9c067f540ac5ea8f41c4ebc107c71613d2dbf19058fa70c75
#   Stored in directory: /private/var/folders/t6/zc4n8b2j6rdcj9p7xb7gxm0h0000gn/T/pip-ephem-wheel-cache-lffjccqg/wheels/4a/32/93/52fbb4c7444b6e61959c8ab3a23fc83235177722e65d7539ec
# Successfully built neuralprophet
# Installing collected packages: webencodings, Send2Trash, pytz, pymeeus, mistune, korean-lunar-calendar, kaleido, ipython-genutils, fastjsonschema, ephem, zipp, typing-extensions, tqdm, tinycss2, terminado, tenacity, soupsieve, pyrsistent, pycparser, prometheus-client, pkgutil-resolve-name, pillow, pandocfilters, numpy, MarkupSafe, lxml, kiwisolver, jupyterlab-widgets, jupyterlab-pygments, hijri-converter, fonttools, defusedxml, cycler, convertdate, bleach, attrs, torch, plotly, pandas, matplotlib, LunarCalendar, jinja2, importlib-resources, holidays, cffi, beautifulsoup4, torch-lr-finder, jsonschema, argon2-cffi-bindings, nbformat, argon2-cffi, nbclient, nbconvert, notebook, widgetsnbextension, ipywidgets, neuralprophet
# Successfully installed LunarCalendar-0.0.9 MarkupSafe-2.1.1 Send2Trash-1.8.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 attrs-22.1.0 beautifulsoup4-4.11.1 bleach-5.0.1 cffi-1.15.1 convertdate-2.4.0 cycler-0.11.0 defusedxml-0.7.1 ephem-4.1.3 fastjsonschema-2.16.1 fonttools-4.34.4 hijri-converter-2.2.4 holidays-0.14.2 importlib-resources-5.9.0 ipython-genutils-0.2.0 ipywidgets-7.7.1 jinja2-3.1.2 jsonschema-4.9.1 jupyterlab-pygments-0.2.2 jupyterlab-widgets-1.1.1 kaleido-0.2.1 kiwisolver-1.4.4 korean-lunar-calendar-0.2.1 lxml-4.9.1 matplotlib-3.5.3 mistune-0.8.4 nbclient-0.6.6 nbconvert-6.5.3 nbformat-5.4.0 neuralprophet-0.3.3 notebook-6.4.12 numpy-1.23.1 pandas-1.4.3 pandocfilters-1.5.0 pillow-9.2.0 pkgutil-resolve-name-1.3.10 plotly-5.10.0 prometheus-client-0.14.1 pycparser-2.21 pymeeus-0.5.11 pyrsistent-0.18.1 pytz-2022.2 soupsieve-2.3.2.post1 tenacity-8.0.1 terminado-0.15.0 tinycss2-1.1.1 torch-1.12.1 torch-lr-finder-0.2.1 tqdm-4.64.0 typing-extensions-4.3.0 webencodings-0.5.1 widgetsnbextension-3.6.1 zipp-3.8.1

# %%
import pickle
import pandas as pd
from neuralprophet import NeuralProphet, set_log_level

# %%
target_column = 'Total Vertical TBS'

df = pd.read_csv('https://raw.githubusercontent.com/drdevinhopkins/hourly-report/main/data/since-2020.csv')
df.ds = pd.to_datetime(df.ds)
df = df.drop(['Date', 'Time'], axis=1)
df = df.sort_values(by='ds', ascending=True)
df.rename(columns = {target_column:'y', 'Adm. requests cum':"Adm requests cum", 'Pts.waiting for admission CUM':'Pts waiting for admission CUM'}, inplace = True)
df.dropna(inplace=True)
regressors = df.columns.tolist()
regressors.remove('y')
regressors.remove('ds')

m = NeuralProphet(
  # growth='off',
  # yearly_seasonality=False,
  # weekly_seasonality=True,
  # daily_seasonality=True,
  n_lags=48,
  n_forecasts=12,
  # changepoints_range=0.95,
  # n_changepoints=50,
  # num_hidden_layers=4,
  # d_hidden=36,
  # learning_rate=0.005,
)
m = m.add_lagged_regressor(names=regressors)
m = m.add_country_holidays("CA")
metrics = m.fit(df, 
                freq='H', 
                # progress='plot'
                )
print(metrics.tail(1))

with open('../models/verticalTBS_forecast_model.pkl', "wb") as f:
    pickle.dump(m, f)
# Out:
# INFO - (NP.forecaster.add_lagged_regressor) - n_lags = 'auto', number of lags for regressor is set to Autoregression number of lags (48)
# INFO - (NP.df_utils._infer_frequency) - Major frequency H corresponds to 99.439% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - H
# INFO - (NP.forecaster.__handle_missing_data) - 63 missing dates added.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column y were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column y were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Stretcher Pts hrly were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Stretcher Pts hrly were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Stretcher Pts cum were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Stretcher Pts cum were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Ambulatory Pts hrly were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Ambulatory Pts hrly were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Ambulatory Pts cum were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Ambulatory Pts cum were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Total Inflow hrly were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Total Inflow hrly were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Total Inflow cum were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Total Inflow cum were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Ambulances hrly were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Ambulances hrly were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Ambulances cum were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Ambulances cum were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column FLS hrly were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column FLS hrly were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Adm requests cum were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Adm requests cum were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Admissions cum were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Admissions cum were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Pts waiting for admission CUM were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Pts waiting for admission CUM were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Total Stretcher pts were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Total Stretcher pts were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Triage hallway pts were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Triage hallway pts were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Triage hallway pts TBS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Triage hallway pts TBS were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Re-Oriented Nurse cum were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Re-Oriented Nurse cum were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Re-Oriented MD QTrack D/C were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Re-Oriented MD QTrack D/C were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Re-Oriented MD QTrack NotD/C were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Re-Oriented MD QTrack NotD/C were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Resus Pts were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Resus Pts were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Totalpts in PODs except Psych were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Totalpts in PODs except Psych were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Green Pts were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Green Pts were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Green Pts TBS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Green Pts TBS were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Yellow PTS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Yellow PTS were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Yellow Pts TBS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Yellow Pts TBS were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Orancge Pts except psych were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Orancge Pts except psych were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Orange Pts TBS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Orange Pts TBS were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Consults > 2h in PODS except IM were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Consults > 2h in PODS except IM were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Consult for IM >4h in PODS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Consult for IM >4h in PODS were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Plain films reqs > 2 h in PODs were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Plain films reqs > 2 h in PODs were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column CTs reqs > 2 h in PODs were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column CTs reqs > 2 h in PODs were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Post POD (Family room) were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Post POD (Family room) were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Stretcher Pts in Vertical were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Stretcher Pts in Vertical were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Stretcher Pts TBS in Vertical were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Stretcher Pts TBS in Vertical were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Stretcher Pts in Vertical on Lazyboy were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Stretcher Pts in Vertical on Lazyboy were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Vertical Pts Waiting for Results were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Vertical Pts Waiting for Results were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Ambulatory Pts in Vertical were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Ambulatory Pts in Vertical were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Ambulatory Pts TBS in Vertical were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Ambulatory Pts TBS in Vertical were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column QTrack Patients TBS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column QTrack Patients TBS were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column GARAGE patient TBS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column GARAGE patient TBS were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Consults > 2h in Vertical Except IM were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Consults > 2h in Vertical Except IM were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Consult for IM >4h in Vertical were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Consult for IM >4h in Vertical were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Plain films reqs > 2 hr in Vertical were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Plain films reqs > 2 hr in Vertical were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column CTs reqs > 2 hrs in Vertical were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column CTs reqs > 2 hrs in Vertical were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Psych Stretcher Pts1pt were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Psych Stretcher Pts1pt were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Psych pts waiting for admission were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Psych pts waiting for admission were auto-imputed.
# WARNING - (NP.forecaster.__handle_missing_data) - 63 missing values in column Total Pod TBS were detected in total.
# INFO - (NP.forecaster.__handle_missing_data) - 63 NaN values in column Total Pod TBS were auto-imputed.
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 105
#   0%|          | 0/149 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 7.80E-04, min: 2.58E-02
#   0%|          | 0/149 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 7.80E-04, min: 4.52E-02
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 3.93E-03
# Epoch[105/105]: 100%|██████████| 105/105 [03:33<00:00,  2.03s/it, SmoothL1Loss=0.0143, MAE=4.12, RMSE=5.23, Loss=0.0105, RegLoss=0]
#      SmoothL1Loss       MAE      RMSE     Loss  RegLoss
# 104      0.014331  4.121945  5.234521  0.01051      0.0

# %%
# loaded_model = pickle.load(open('../models/verticalTBS_forecast_model.pkl', 'rb'))
loaded_model = m

# %%
target_column = 'Total Vertical TBS'
df = pd.read_csv('https://raw.githubusercontent.com/drdevinhopkins/hourly-report/main/data/since-2020.csv')
df.ds = pd.to_datetime(df.ds)
df = df.drop(['Date', 'Time'], axis=1)
df = df.sort_values(by='ds', ascending=True)
df.rename(columns = {target_column:'y', 'Adm. requests cum':"Adm requests cum", 'Pts.waiting for admission CUM':'Pts waiting for admission CUM'}, inplace = True)
df.dropna(inplace=True)
regressors = df.columns.tolist()
regressors.remove('y')
regressors.remove('ds')
# df['ID']='test'

# %%
df.head()
# Out:
#       Stretcher Pts hrly  Stretcher Pts cum  Ambulatory Pts hrly  \
# 9097                   9                108                    5
# 9096                   5                113                    6
# 9095                   5                118                    2
# 9094                   5                123                    8
# 9093                   3                126                    7
#
#       Ambulatory Pts cum  Total Inflow hrly  Total Inflow cum  \
# 9097                 142                 14               250
# 9096                 148                 11               261
# 9095                 150                  7               268
# 9094                 158                 13               281
# 9093                 165                 10               291
#
#       Ambulances hrly  Ambulances cum  FLS hrly  Adm requests cum  ...  \
# 9097                6              39         0                27  ...
# 9096                2              41         0                33  ...
# 9095                1              42         0                34  ...
# 9094                2              44         0                34  ...
# 9093                3              47         0                37  ...
#
#       GARAGE patient TBS  Consults > 2h in Vertical Except IM  \
# 9097                 1.0                                    1
# 9096                 1.0                                    1
# 9095                 0.0                                    1
# 9094                 0.0                                    1
# 9093                 1.0                                    0
#
#       Consult for IM >4h in Vertical  Plain films reqs > 2 hr in Vertical  \
# 9097                               0                                    0
# 9096                               0                                    0
# 9095                               0                                    0
# 9094                               0                                    0
# 9093                               0                                    1
#
#       CTs reqs > 2 hrs in Vertical  Psych Stretcher Pts1pt  \
# 9097                             3                       0
# 9096                             3                       1
# 9095                             4                       4
# 9094                             3                       5
# 9093                             3                       6
#
#       Psych pts waiting for admission                  ds  Total Pod TBS     y
# 9097                                0 2021-07-26 19:00:00             10  18.0
# 9096                                0 2021-07-26 20:00:00             12   9.0
# 9095                                0 2021-07-26 21:00:00              8   4.0
# 9094                                0 2021-07-26 22:00:00              9   6.0
# 9093                                0 2021-07-26 23:00:00             10  11.0
#
# [5 rows x 48 columns]

# %%
future = loaded_model.make_future_dataframe(df, periods=12) # periods=m.n_forecasts, n_historic_predictions=False
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency H corresponds to 99.439% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - H
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column

# %%
future.tail()
# Out:
#    Stretcher Pts hrly Stretcher Pts cum Ambulatory Pts hrly  \
# 55               None              None                None
# 56               None              None                None
# 57               None              None                None
# 58               None              None                None
# 59               None              None                None
#
#    Ambulatory Pts cum Total Inflow hrly Total Inflow cum Ambulances hrly  \
# 55               None              None             None            None
# 56               None              None             None            None
# 57               None              None             None            None
# 58               None              None             None            None
# 59               None              None             None            None
#
#    Ambulances cum FLS hrly Adm requests cum  ... GARAGE patient TBS  \
# 55           None     None             None  ...                NaN
# 56           None     None             None  ...                NaN
# 57           None     None             None  ...                NaN
# 58           None     None             None  ...                NaN
# 59           None     None             None  ...                NaN
#
#    Consults > 2h in Vertical Except IM Consult for IM >4h in Vertical  \
# 55                                None                           None
# 56                                None                           None
# 57                                None                           None
# 58                                None                           None
# 59                                None                           None
#
#    Plain films reqs > 2 hr in Vertical CTs reqs > 2 hrs in Vertical  \
# 55                                None                         None
# 56                                None                         None
# 57                                None                         None
# 58                                None                         None
# 59                                None                         None
#
#    Psych Stretcher Pts1pt Psych pts waiting for admission                  ds  \
# 55                   None                            None 2022-08-12 19:00:00
# 56                   None                            None 2022-08-12 20:00:00
# 57                   None                            None 2022-08-12 21:00:00
# 58                   None                            None 2022-08-12 22:00:00
# 59                   None                            None 2022-08-12 23:00:00
#
#    Total Pod TBS   y
# 55          None NaN
# 56          None NaN
# 57          None NaN
# 58          None NaN
# 59          None NaN
#
# [5 rows x 48 columns]

# %%
forecast = loaded_model.predict(
    future, 
    # raw=True, 
    decompose=False
    )
# forecast = loaded_model.predict(future)
forecast
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency H corresponds to 98.333% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - H
# INFO - (NP.df_utils._infer_frequency) - Major frequency H corresponds to 98.333% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - H
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
#                     ds     y residual1      yhat1 residual2      yhat2  \
# 0  2022-08-10 12:00:00  24.0       NaN       None       NaN       None
# 1  2022-08-10 13:00:00  26.0       NaN       None       NaN       None
# 2  2022-08-10 14:00:00  31.0       NaN       None       NaN       None
# 3  2022-08-10 15:00:00  23.0       NaN       None       NaN       None
# 4  2022-08-10 16:00:00  27.0       NaN       None       NaN       None
# 5  2022-08-10 17:00:00  19.0       NaN       None       NaN       None
# 6  2022-08-10 18:00:00  18.0       NaN       None       NaN       None
# 7  2022-08-10 19:00:00  17.0       NaN       None       NaN       None
# 8  2022-08-10 20:00:00  20.0       NaN       None       NaN       None
# 9  2022-08-10 21:00:00  19.0       NaN       None       NaN       None
# 10 2022-08-10 22:00:00  20.0       NaN       None       NaN       None
# 11 2022-08-10 23:00:00  22.0       NaN       None       NaN       None
# 12 2022-08-11 00:00:00  23.0       NaN       None       NaN       None
# 13 2022-08-11 01:00:00  18.0       NaN       None       NaN       None
# 14 2022-08-11 02:00:00  14.0       NaN       None       NaN       None
# 15 2022-08-11 03:00:00  13.0       NaN       None       NaN       None
# 16 2022-08-11 04:00:00  11.0       NaN       None       NaN       None
# 17 2022-08-11 05:00:00   9.0       NaN       None       NaN       None
# 18 2022-08-11 06:00:00   6.0       NaN       None       NaN       None
# 19 2022-08-11 07:00:00   4.0       NaN       None       NaN       None
# 20 2022-08-11 08:00:00  10.0       NaN       None       NaN       None
# 21 2022-08-11 09:00:00   4.0       NaN       None       NaN       None
# 22 2022-08-11 10:00:00   9.0       NaN       None       NaN       None
# 23 2022-08-11 11:00:00   7.0       NaN       None       NaN       None
# 24 2022-08-11 12:00:00   4.0       NaN       None       NaN       None
# 25 2022-08-11 13:00:00   4.0       NaN       None       NaN       None
# 26 2022-08-11 14:00:00   8.0       NaN       None       NaN       None
# 27 2022-08-11 15:00:00  13.0       NaN       None       NaN       None
# 28 2022-08-11 16:00:00  18.0       NaN       None       NaN       None
# 29 2022-08-11 17:00:00  10.0       NaN       None       NaN       None
# 30 2022-08-11 18:00:00   8.0       NaN       None       NaN       None
# 31 2022-08-11 19:00:00  13.0       NaN       None       NaN       None
# 32 2022-08-11 20:00:00  13.0       NaN       None       NaN       None
# 33 2022-08-11 21:00:00  13.0       NaN       None       NaN       None
# 34 2022-08-11 22:00:00  12.0       NaN       None       NaN       None
# 35 2022-08-11 23:00:00  11.0       NaN       None       NaN       None
# 36 2022-08-12 00:00:00  11.0       NaN       None       NaN       None
# 37 2022-08-12 01:00:00  14.0       NaN       None       NaN       None
# 38 2022-08-12 02:00:00  16.0       NaN       None       NaN       None
# 39 2022-08-12 03:00:00  16.0       NaN       None       NaN       None
# 40 2022-08-12 04:00:00  18.0       NaN       None       NaN       None
# 41 2022-08-12 05:00:00  17.0       NaN       None       NaN       None
# 42 2022-08-12 06:00:00  17.0       NaN       None       NaN       None
# 43 2022-08-12 07:00:00  15.0       NaN       None       NaN       None
# 44 2022-08-12 08:00:00  17.0       NaN       None       NaN       None
# 45 2022-08-12 09:00:00  11.0       NaN       None       NaN       None
# 46 2022-08-12 10:00:00  11.0       NaN       None       NaN       None
# 47 2022-08-12 11:00:00  15.0       NaN       None       NaN       None
# 48 2022-08-12 12:00:00   NaN       NaN  19.287329       NaN       None
# 49 2022-08-12 13:00:00   NaN       NaN       None       NaN  18.646053
# 50 2022-08-12 14:00:00   NaN       NaN       None       NaN       None
# 51 2022-08-12 15:00:00   NaN       NaN       None       NaN       None
# 52 2022-08-12 16:00:00   NaN       NaN       None       NaN       None
# 53 2022-08-12 17:00:00   NaN       NaN       None       NaN       None
# 54 2022-08-12 18:00:00   NaN       NaN       None       NaN       None
# 55 2022-08-12 19:00:00   NaN       NaN       None       NaN       None
# 56 2022-08-12 20:00:00   NaN       NaN       None       NaN       None
# 57 2022-08-12 21:00:00   NaN       NaN       None       NaN       None
# 58 2022-08-12 22:00:00   NaN       NaN       None       NaN       None
# 59 2022-08-12 23:00:00   NaN       NaN       None       NaN       None
#
#    residual3      yhat3 residual4      yhat4  ... residual8     yhat8  \
# 0        NaN       None       NaN       None  ...       NaN      None
# 1        NaN       None       NaN       None  ...       NaN      None
# 2        NaN       None       NaN       None  ...       NaN      None
# 3        NaN       None       NaN       None  ...       NaN      None
# 4        NaN       None       NaN       None  ...       NaN      None
# 5        NaN       None       NaN       None  ...       NaN      None
# 6        NaN       None       NaN       None  ...       NaN      None
# 7        NaN       None       NaN       None  ...       NaN      None
# 8        NaN       None       NaN       None  ...       NaN      None
# 9        NaN       None       NaN       None  ...       NaN      None
# 10       NaN       None       NaN       None  ...       NaN      None
# 11       NaN       None       NaN       None  ...       NaN      None
# 12       NaN       None       NaN       None  ...       NaN      None
# 13       NaN       None       NaN       None  ...       NaN      None
# 14       NaN       None       NaN       None  ...       NaN      None
# 15       NaN       None       NaN       None  ...       NaN      None
# 16       NaN       None       NaN       None  ...       NaN      None
# 17       NaN       None       NaN       None  ...       NaN      None
# 18       NaN       None       NaN       None  ...       NaN      None
# 19       NaN       None       NaN       None  ...       NaN      None
# 20       NaN       None       NaN       None  ...       NaN      None
# 21       NaN       None       NaN       None  ...       NaN      None
# 22       NaN       None       NaN       None  ...       NaN      None
# 23       NaN       None       NaN       None  ...       NaN      None
# 24       NaN       None       NaN       None  ...       NaN      None
# 25       NaN       None       NaN       None  ...       NaN      None
# 26       NaN       None       NaN       None  ...       NaN      None
# 27       NaN       None       NaN       None  ...       NaN      None
# 28       NaN       None       NaN       None  ...       NaN      None
# 29       NaN       None       NaN       None  ...       NaN      None
# 30       NaN       None       NaN       None  ...       NaN      None
# 31       NaN       None       NaN       None  ...       NaN      None
# 32       NaN       None       NaN       None  ...       NaN      None
# 33       NaN       None       NaN       None  ...       NaN      None
# 34       NaN       None       NaN       None  ...       NaN      None
# 35       NaN       None       NaN       None  ...       NaN      None
# 36       NaN       None       NaN       None  ...       NaN      None
# 37       NaN       None       NaN       None  ...       NaN      None
# 38       NaN       None       NaN       None  ...       NaN      None
# 39       NaN       None       NaN       None  ...       NaN      None
# 40       NaN       None       NaN       None  ...       NaN      None
# 41       NaN       None       NaN       None  ...       NaN      None
# 42       NaN       None       NaN       None  ...       NaN      None
# 43       NaN       None       NaN       None  ...       NaN      None
# 44       NaN       None       NaN       None  ...       NaN      None
# 45       NaN       None       NaN       None  ...       NaN      None
# 46       NaN       None       NaN       None  ...       NaN      None
# 47       NaN       None       NaN       None  ...       NaN      None
# 48       NaN       None       NaN       None  ...       NaN      None
# 49       NaN       None       NaN       None  ...       NaN      None
# 50       NaN  21.020023       NaN       None  ...       NaN      None
# 51       NaN       None       NaN  19.545578  ...       NaN      None
# 52       NaN       None       NaN       None  ...       NaN      None
# 53       NaN       None       NaN       None  ...       NaN      None
# 54       NaN       None       NaN       None  ...       NaN      None
# 55       NaN       None       NaN       None  ...       NaN  9.325451
# 56       NaN       None       NaN       None  ...       NaN      None
# 57       NaN       None       NaN       None  ...       NaN      None
# 58       NaN       None       NaN       None  ...       NaN      None
# 59       NaN       None       NaN       None  ...       NaN      None
#
#    residual9      yhat9 residual10     yhat10 residual11    yhat11 residual12  \
# 0        NaN       None        NaN       None        NaN      None        NaN
# 1        NaN       None        NaN       None        NaN      None        NaN
# 2        NaN       None        NaN       None        NaN      None        NaN
# 3        NaN       None        NaN       None        NaN      None        NaN
# 4        NaN       None        NaN       None        NaN      None        NaN
# 5        NaN       None        NaN       None        NaN      None        NaN
# 6        NaN       None        NaN       None        NaN      None        NaN
# 7        NaN       None        NaN       None        NaN      None        NaN
# 8        NaN       None        NaN       None        NaN      None        NaN
# 9        NaN       None        NaN       None        NaN      None        NaN
# 10       NaN       None        NaN       None        NaN      None        NaN
# 11       NaN       None        NaN       None        NaN      None        NaN
# 12       NaN       None        NaN       None        NaN      None        NaN
# 13       NaN       None        NaN       None        NaN      None        NaN
# 14       NaN       None        NaN       None        NaN      None        NaN
# 15       NaN       None        NaN       None        NaN      None        NaN
# 16       NaN       None        NaN       None        NaN      None        NaN
# 17       NaN       None        NaN       None        NaN      None        NaN
# 18       NaN       None        NaN       None        NaN      None        NaN
# 19       NaN       None        NaN       None        NaN      None        NaN
# 20       NaN       None        NaN       None        NaN      None        NaN
# 21       NaN       None        NaN       None        NaN      None        NaN
# 22       NaN       None        NaN       None        NaN      None        NaN
# 23       NaN       None        NaN       None        NaN      None        NaN
# 24       NaN       None        NaN       None        NaN      None        NaN
# 25       NaN       None        NaN       None        NaN      None        NaN
# 26       NaN       None        NaN       None        NaN      None        NaN
# 27       NaN       None        NaN       None        NaN      None        NaN
# 28       NaN       None        NaN       None        NaN      None        NaN
# 29       NaN       None        NaN       None        NaN      None        NaN
# 30       NaN       None        NaN       None        NaN      None        NaN
# 31       NaN       None        NaN       None        NaN      None        NaN
# 32       NaN       None        NaN       None        NaN      None        NaN
# 33       NaN       None        NaN       None        NaN      None        NaN
# 34       NaN       None        NaN       None        NaN      None        NaN
# 35       NaN       None        NaN       None        NaN      None        NaN
# 36       NaN       None        NaN       None        NaN      None        NaN
# 37       NaN       None        NaN       None        NaN      None        NaN
# 38       NaN       None        NaN       None        NaN      None        NaN
# 39       NaN       None        NaN       None        NaN      None        NaN
# 40       NaN       None        NaN       None        NaN      None        NaN
# 41       NaN       None        NaN       None        NaN      None        NaN
# 42       NaN       None        NaN       None        NaN      None        NaN
# 43       NaN       None        NaN       None        NaN      None        NaN
# 44       NaN       None        NaN       None        NaN      None        NaN
# 45       NaN       None        NaN       None        NaN      None        NaN
# 46       NaN       None        NaN       None        NaN      None        NaN
# 47       NaN       None        NaN       None        NaN      None        NaN
# 48       NaN       None        NaN       None        NaN      None        NaN
# 49       NaN       None        NaN       None        NaN      None        NaN
# 50       NaN       None        NaN       None        NaN      None        NaN
# 51       NaN       None        NaN       None        NaN      None        NaN
# 52       NaN       None        NaN       None        NaN      None        NaN
# 53       NaN       None        NaN       None        NaN      None        NaN
# 54       NaN       None        NaN       None        NaN      None        NaN
# 55       NaN       None        NaN       None        NaN      None        NaN
# 56       NaN  10.364691        NaN       None        NaN      None        NaN
# 57       NaN       None        NaN  10.015965        NaN      None        NaN
# 58       NaN       None        NaN       None        NaN  9.118239        NaN
# 59       NaN       None        NaN       None        NaN      None        NaN
#
#        yhat12
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
# 31       None
# 32       None
# 33       None
# 34       None
# 35       None
# 36       None
# 37       None
# 38       None
# 39       None
# 40       None
# 41       None
# 42       None
# 43       None
# 44       None
# 45       None
# 46       None
# 47       None
# 48       None
# 49       None
# 50       None
# 51       None
# 52       None
# 53       None
# 54       None
# 55       None
# 56       None
# 57       None
# 58       None
# 59  13.377767
#
# [60 rows x 26 columns]

# %%
forecast_trimmed = forecast[forecast.y.isnull()].set_index('ds')

# %%
start = forecast_trimmed.index.tolist()[0]
forecast_length = len(forecast_trimmed.index.tolist())

# %%
i = 0
timestamp = pd.Timestamp.now().round('S').replace(tzinfo=None)
forecast_output_list = []
for ds in pd.date_range(start=start, periods=forecast_length, freq='H'):
    i = i+1
    forecast_output_list.append({'ds':ds, 'verticalTBS':forecast_trimmed.loc[ds]['yhat'+str(i)], 'timestamp':timestamp})
forecast_output = pd.DataFrame(forecast_output_list)
forecast_output
# Out:
#                     ds  verticalTBS           timestamp
# 0  2022-08-12 12:00:00    19.287329 2022-08-12 12:14:27
# 1  2022-08-12 13:00:00    18.646053 2022-08-12 12:14:27
# 2  2022-08-12 14:00:00    21.020023 2022-08-12 12:14:27
# 3  2022-08-12 15:00:00    19.545578 2022-08-12 12:14:27
# 4  2022-08-12 16:00:00    22.569710 2022-08-12 12:14:27
# 5  2022-08-12 17:00:00    17.739473 2022-08-12 12:14:27
# 6  2022-08-12 18:00:00    12.435977 2022-08-12 12:14:27
# 7  2022-08-12 19:00:00     9.325451 2022-08-12 12:14:27
# 8  2022-08-12 20:00:00    10.364691 2022-08-12 12:14:27
# 9  2022-08-12 21:00:00    10.015965 2022-08-12 12:14:27
# 10 2022-08-12 22:00:00     9.118239 2022-08-12 12:14:27
# 11 2022-08-12 23:00:00    13.377767 2022-08-12 12:14:27
